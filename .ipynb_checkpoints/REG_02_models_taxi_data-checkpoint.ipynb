# %% [markdown]
# # Régression - NYC taxis
#
# La deuxième cellule de ce notebook charge les données générées par le notebook `REG_01`.

# %%
import pandas as pd
import numpy as np
import pyarrow.parquet as pq
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, Ridge
from sklearn.linear_model import LassoCV, RidgeCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import root_mean_squared_error
import lightgbm as lgb

from utils import *

# %%
df_train = pd.read_parquet("data/nyc-taxis-tips/train_preprocessed.parquet")
X = df_train.drop("tip_amount", axis=1)
Y = df_train['tip_amount']
display(X.columns)
print(X.shape)

test = pd.read_parquet("data/nyc-taxis-tips/test_preprocessed.parquet")
test.drop(columns=["RatecodeID_6.0"], inplace=True)
print(test.shape)
# Out:
# Index(['passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tolls_amount', 'improvement_surcharge', 'congestion_surcharge',
#        'Airport_fee', 'PU_location_lat', 'PU_location_lon', 'DO_location_lat',
#        'DO_location_lon', 'is_rush_hour', 'duration', 'PU_loc', 'DO_loc',
#        'VendorID_1', 'VendorID_2', 'RatecodeID_1.0', 'RatecodeID_2.0',
#        'RatecodeID_3.0', 'RatecodeID_4.0', 'RatecodeID_5.0', 'RatecodeID_99.0',
#        'store_and_fwd_flag_N', 'store_and_fwd_flag_Y', 'payment_type_1',
#        'payment_type_2', 'payment_type_3', 'payment_type_4', 'PU_borough_7',
#        'PU_borough_1', 'PU_borough_3', 'PU_borough_4', 'PU_borough_2',
#        'PU_borough_6', 'PU_borough_5', 'DO_borough_7', 'DO_borough_1',
#        'DO_borough_3', 'DO_borough_4', 'DO_borough_2', 'DO_borough_6',
#        'DO_borough_5'],
#       dtype='object')
# (100000, 45)

# %%
# divise les données 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=42)
print(X_train.columns)
print(X_train.shape, X_test.shape)
# Out:
# Index(['passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tolls_amount', 'improvement_surcharge', 'congestion_surcharge',
#        'Airport_fee', 'PU_location_lat', 'PU_location_lon', 'DO_location_lat',
#        'DO_location_lon', 'is_rush_hour', 'duration', 'PU_loc', 'DO_loc',
#        'VendorID_1', 'VendorID_2', 'RatecodeID_1.0', 'RatecodeID_2.0',
#        'RatecodeID_3.0', 'RatecodeID_4.0', 'RatecodeID_5.0', 'RatecodeID_99.0',
#        'store_and_fwd_flag_N', 'store_and_fwd_flag_Y', 'payment_type_1',
#        'payment_type_2', 'payment_type_3', 'payment_type_4', 'PU_borough_7',
#        'PU_borough_1', 'PU_borough_3', 'PU_borough_4', 'PU_borough_2',
#        'PU_borough_6', 'PU_borough_5', 'DO_borough_7', 'DO_borough_1',
#        'DO_borough_3', 'DO_borough_4', 'DO_borough_2', 'DO_borough_6',
#        'DO_borough_5'],
#       dtype='object')
# (75000, 45) (25000, 45)

# %%
# normaliser les données 

# Séparation des colonnes encodées (one-hot encoded) et des colonnes numériques à normaliser
columns_to_norm = [
    'passenger_count',
    'trip_distance', 'fare_amount', 'extra', 'mta_tax', 'tolls_amount',
    'improvement_surcharge', 'congestion_surcharge', 'Airport_fee', 'duration'
]

cols_to_exclude = [
    'PU_location_lat', 'PU_location_lon', 'DO_location_lat',
    'DO_location_lon', 'PU_loc', 'DO_loc'
]

# Copie des colonnes à exclure pour les conserver
X_train_excluded = X_train[cols_to_exclude]
X_test_excluded = X_test[cols_to_exclude]

X_train = X_train.drop(cols_to_exclude, axis=1)
X_test = X_test.drop(cols_to_exclude, axis=1)

# Normaliser les colonnes numériques de l'ensemble d'entraînement
scaler = StandardScaler()
X_train_normed = X_train.copy()
X_test_normed = X_test.copy()

# Normalisation sur l'ensemble d'entraînement
X_train_normed[columns_to_norm] = scaler.fit_transform(X_train[columns_to_norm])

# Appliquer la même transformation sur l'ensemble de test
X_test_normed[columns_to_norm] = scaler.transform(X_test[columns_to_norm])

# Réintégrer les colonnes exclues dans les ensembles normalisés
X_train_normed = pd.concat([X_train_normed, X_train_excluded], axis=1)
X_test_normed = pd.concat([X_test_normed, X_test_excluded], axis=1)

print(X_train_normed.shape)
# Out:
# (75000, 45)

# %%
# test data for Kaggle submission
columns_to_norm = [
    'passenger_count',
    'trip_distance', 'fare_amount', 'extra', 'mta_tax', 'tolls_amount',
    'improvement_surcharge', 'congestion_surcharge', 'Airport_fee', 'duration'
]
cols_to_exclude = [
    'PU_location_lat', 'PU_location_lon', 'DO_location_lat',
    'DO_location_lon', 'PU_loc', 'DO_loc'
]

X_sub_excluded = test[cols_to_exclude]
X_sub = test.drop(cols_to_exclude, axis=1)

X_sub[columns_to_norm] = scaler.transform(X_sub[columns_to_norm])

X_sub = pd.concat([X_sub, X_sub_excluded], axis=1)

# %% [markdown]
# # Ridge regression

# %%
# Modèle Ridge : 
model_ridge_CV = RidgeCV(alphas=np.linspace(1, 25, 100))
model_ridge_CV.fit(X_train_normed, y_train)
y_pred = model_ridge_CV.predict(X_test_normed)

mse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Affichage des résultats
print("Mean Squared Error (MSE):", mse)
print("Coefficient de détermination (R2 Score):", r2)
print("meilleur alpha : ", model_ridge_CV.alpha_)
# Out:
# Mean Squared Error (MSE): 2.301999592151556
# Coefficient de détermination (R2 Score): 0.6113587833569605
# meilleur alpha :  5.121212121212121

# %%
residuals = y_test - y_pred

plt.figure(figsize=(5, 4), dpi=150)
plt.plot(residuals, "o", color='blue', alpha=0.5)
plt.axhline(y=0, color='red', linestyle='--', lw=2)
plt.ylabel("Résidus")
plt.title("Courbe des Résidus")
plt.grid()
plt.show()
plt.savefig("figures/residual_ridge.png")

import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5, 4), dpi=150)
plt.scatter(y_test, y_pred, color='blue', alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--', lw=2)
plt.xlabel("Valeurs Réelles")
plt.ylabel("Valeurs Prédites")
plt.title("Courbe Observé vs Prédit")
plt.grid()
plt.show()
plt.savefig("figures/obs_predicted_ridge.pdf")

# %%
predictions = model_ridge_CV.predict(X_sub)

df_pred = pd.DataFrame(predictions, columns=["tip_amount"]).reset_index().rename(columns={"index": "row_ID"})
display(df_pred.head(15))
print(sum(df_pred["tip_amount"] < 0))
df_pred.loc[df_pred.tip_amount < 0, "tip_amount"] = 0
#df_pred.to_parquet("submission/nyc-taxis-tips/regression_sub_1bis.parquet", index=False)
df_pred.to_parquet("submission/nyc-taxis-tips/Ridge_sub_1.parquet", index=False)
# Out:
#     row_ID  tip_amount
# 0        0    2.015726
# 1        1    3.036563
# 2        2   -2.201379
# 3        3    2.536987
# 4        4   -1.631438
# 5        5    6.483613
# 6        6    4.070212
# 7        7   -1.851042
# 8        8    3.414829
# 9        9    7.529063
# 10      10    5.642042
# 11      11    2.914963
# 12      12    3.894848
# 13      13    2.878176
# 14      14    3.275075
# 332088

# %% [markdown]
# # Random Forest Regressor

# %%
#  modèle Random Forest
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 3, 5],
    'min_samples_leaf': [50, 75, 100], # previously tested [30, 40, 50] which lead to 50 as best one
}

# Modèle RandomForest
rf_model = RandomForestRegressor(random_state=42)

# RandomizedSearchCV pour optimiser les hyperparamètres
rf_grid = GridSearchCV(estimator=rf_model,
                       param_grid=param_grid,
                       cv=5,
                       verbose=2,
                       n_jobs=-1)  # Utiliser tous les cœurs disponibles

# Entraîner le modèle avecGridSearchCV sur les données normalisées
rf_grid.fit(X, Y)

# Meilleurs hyperparamètres trouvés
best_params = rf_grid.best_params_

# Affichage des résultats
print("Meilleurs hyperparamètres trouvés:", best_params)
print("Coefficient de détermination (R2 Score):", rf_grid.best_score_)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Meilleurs hyperparamètres trouvés: {'max_depth': 10, 'min_samples_leaf': 50, 'min_samples_split': 2, 'n_estimators': 200}
# Coefficient de détermination (R2 Score): 0.7083010646201731

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5, 4), dpi=150)
plt.scatter(y_test, y_pred, color='blue', alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--', lw=2)
plt.xlabel("Valeurs Réelles")
plt.ylabel("Valeurs Prédites")
plt.title("Courbe Observé vs Prédit")
plt.grid()
plt.show()
plt.savefig("figures/obs_predicted_rf.pdf")


residuals = y_test - y_pred

plt.figure(figsize=(5, 4), dpi=150)
plt.plot(residuals, "o", color='blue', alpha=0.5)
plt.axhline(y=0, color='red', linestyle='--', lw=2)
plt.ylabel("Résidus")
plt.title("Courbe des Résidus")
plt.grid()
plt.show()
plt.savefig("figures/residual_rf.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       2 import numpy as np
#       4 plt.figure(figsize=(5, 4), dpi=150)
# ----> 5 plt.scatter(y_test, y_pred, color='blue', alpha=0.5)
#       6 plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--', lw=2)
#       7 plt.xlabel("Valeurs Réelles")
#
# NameError: name 'y_pred' is not defined

# %%
print(rf_grid.cv_results_)
# Out:
# {'mean_fit_time': array([41.61585126, 40.73262329, 37.20319591]), 'std_fit_time': array([3.10827865, 4.05464705, 0.77195188]), 'mean_score_time': array([0.22823358, 0.21604524, 0.20060973]), 'std_score_time': array([0.0228883 , 0.02183372, 0.01434354]), 'param_max_depth': masked_array(data=[10, 10, 10],
#              mask=[False, False, False],
#        fill_value=999999), 'param_min_samples_leaf': masked_array(data=[50, 50, 50],
#              mask=[False, False, False],
#        fill_value=999999), 'param_min_samples_split': masked_array(data=[2, 3, 5],
#              mask=[False, False, False],
#        fill_value=999999), 'param_n_estimators': masked_array(data=[200, 200, 200],
#              mask=[False, False, False],
#        fill_value=999999), 'params': [{'max_depth': 10, 'min_samples_leaf': 50, 'min_samples_split': 2, 'n_estimators': 200}, {'max_depth': 10, 'min_samples_leaf': 50, 'min_samples_split': 3, 'n_estimators': 200}, {'max_depth': 10, 'min_samples_leaf': 50, 'min_samples_split': 5, 'n_estimators': 200}], 'split0_test_score': array([0.73875267, 0.73875267, 0.73875267]), 'split1_test_score': array([0.64596483, 0.64596483, 0.64596483]), 'split2_test_score': array([0.7016902, 0.7016902, 0.7016902]), 'split3_test_score': array([0.73178223, 0.73178223, 0.73178223]), 'split4_test_score': array([0.72331539, 0.72331539, 0.72331539]), 'mean_test_score': array([0.70830106, 0.70830106, 0.70830106]), 'std_test_score': array([0.03356666, 0.03356666, 0.03356666]), 'rank_test_score': array([1, 1, 1], dtype=int32)}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 print(rf_grid.cv_results_)
# ----> 2 print(rf_grid.scorer_._estimator.score())
#
# TypeError: RegressorMixin.score() missing 2 required positional arguments: 'X' and 'y'

# %%
#predictions = model_ridge_CV.predict(X_sub)
predictions = rf_grid.predict(test)

# %%
df_pred = pd.DataFrame(predictions, columns=["tip_amount"]).reset_index().rename(columns={"index": "row_ID"})
display(df_pred.head(15))
print(sum(df_pred["tip_amount"] < 0))
df_pred.loc[df_pred.tip_amount < 0, "tip_amount"] = 0
#df_pred.to_parquet("submission/nyc-taxis-tips/regression_sub_1bis.parquet", index=False)
df_pred.to_parquet("submission/nyc-taxis-tips/RF_sub_3.parquet", index=False)
# Out:
#     row_ID  tip_amount
# 0        0    1.651511
# 1        1    2.608744
# 2        2    0.000000
# 3        3    2.000449
# 4        4    0.000000
# 5        5    6.958345
# 6        6    4.382354
# 7        7    0.000000
# 8        8    3.549254
# 9        9    9.425073
# 10      10    6.248322
# 11      11    2.323372
# 12      12    3.953232
# 13      13    2.620380
# 14      14    3.077858
# 0

# %%
sns.histplot(df_pred, x="tip_amount", bins=125)
# Out:
# <Axes: xlabel='tip_amount', ylabel='Count'>
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  23.5s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time=  34.5s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time=  36.1s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  24.2s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  21.1s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  43.4s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time= 1.1min
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  53.0s
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time= 1.2min
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time= 1.1min
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  48.2s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=3, n_estimators=200; total time=  46.3s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  23.6s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  11.4s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  12.0s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  23.3s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  11.6s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  12.4s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time=  36.1s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  21.9s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  43.0s
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time= 1.1min
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  51.7s
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  22.5s
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  23.7s
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time= 1.2min
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  43.1s
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time=  57.8s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=2, n_estimators=200; total time=  39.5s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  36.5s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  12.4s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time=  33.4s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  11.5s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time=  35.8s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  24.1s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  21.2s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  21.9s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  42.6s
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  20.5s
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  20.0s
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  38.7s
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  23.5s
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  24.1s
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  50.8s
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  25.2s
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  50.4s
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  24.1s
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  23.6s
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  44.7s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=2, n_estimators=200; total time=  38.9s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=3, n_estimators=200; total time=  37.1s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  12.4s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time=  34.2s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  22.6s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time=  36.5s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time=  36.3s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  43.7s
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  21.9s
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  22.0s
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  41.3s
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time= 1.1min
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time= 1.2min
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  47.6s
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  21.4s
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  22.2s
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  44.1s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=2, n_estimators=200; total time=  39.5s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  36.5s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  12.5s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time=  34.5s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  23.2s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  11.7s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  24.5s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time=  36.3s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  44.2s
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  21.8s
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  43.5s
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time= 1.0min
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  52.0s
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time= 1.2min
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time= 1.2min
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time= 1.0min
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=3, n_estimators=200; total time=  39.4s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=3, n_estimators=200; total time=  36.7s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  12.4s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  22.5s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  11.9s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  23.3s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  11.7s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  12.3s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  24.3s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  21.9s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  42.7s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time= 1.0min
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  42.5s
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  27.2s
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  52.6s
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  23.0s
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  23.1s
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  47.2s
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  22.2s
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  46.4s
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time= 1.0min
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=3, n_estimators=200; total time=  45.3s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  38.1s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  12.1s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  22.5s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  11.4s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  23.3s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time=  36.3s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time=  35.2s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  43.6s
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  21.9s
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=100; total time=  22.2s
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  43.1s
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  21.2s
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  42.3s
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time= 1.1min
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time= 1.2min
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  45.7s
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time= 1.2min
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time= 1.0min
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=2, n_estimators=200; total time=  45.5s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  38.1s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  23.0s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time=  34.6s
# [CV] END max_depth=5, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time=  35.3s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  23.5s
# [CV] END max_depth=5, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time=  37.1s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  43.3s
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  21.0s
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=100; total time=  21.4s
# [CV] END max_depth=10, min_samples_leaf=100, min_samples_split=5, n_estimators=200; total time=  42.1s
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  26.8s
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=  27.1s
# [CV] END max_depth=15, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time= 1.3min
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=200; total time=  47.3s
# [CV] END max_depth=15, min_samples_leaf=75, min_samples_split=5, n_estimators=300; total time= 1.2min
# [CV] END max_depth=15, min_samples_leaf=100, min_samples_split=5, n_estimators=300; total time= 1.0min
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=2, n_estimators=200; total time=  45.9s
# [CV] END max_depth=10, min_samples_leaf=50, min_samples_split=5, n_estimators=200; total time=  37.9s

# %% [markdown]
# # Gradient boosting

# %%
gbm = lgb.LGBMRegressor(num_leaves=10, learning_rate=0.05, n_estimators=100)
gbm.fit(X_train, y_train, eval_set=[(X_test, y_test)], eval_metric="l1", callbacks=[lgb.early_stopping(5)])

# predict
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration_)
# eval
rmsle_test = rmsle(y_test, y_pred)[1]
rae_test = rae(y_test, y_pred)[1]
print(f"The RMSLE of prediction is: {rmsle_test}")
print(f"The RAE of prediction is: {rae_test}")
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006068 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 871
# [LightGBM] [Info] Number of data points in the train set: 75000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.429543
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [87]	valid_0's l1: 1.00306	valid_0's l2: 4.10562
# The RMSLE of prediction is: 0.39367960248656836
# The RAE of prediction is: 0.4256999813473063
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.054339 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.034714 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012801 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.037335 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.037588 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031022 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030913 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011863 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031945 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.040971 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011520 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.044933 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.033614 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026812 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024053 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.033095 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039825 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012328 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012706 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011183 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.027001 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.049039 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020710 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017356 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.045889 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014600 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039848 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.054522 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031215 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.013232 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.037836 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.029090 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.036815 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009002 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030648 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.033568 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011577 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.034586 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015201 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.046650 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.029288 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.024552 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040782 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.038497 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015250 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019512 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.033652 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.044246 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013780 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.029214 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.036255 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011101 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039902 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.057759 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012815 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020892 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011063 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008676 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.048547 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016197 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040918 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.037019 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.035159 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.052332 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.051164 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019688 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.033526 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.033508 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012455 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.032877 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011914 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.030649 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.048864 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012090 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.053122 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016046 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012876 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032801 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026525 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038694 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028503 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.034132 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.033039 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.021288 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011987 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.040011 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031982 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012274 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.029348 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.021353 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.043012 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.044774 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013320 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.029027 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.022828 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011757 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012323 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.045277 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.030042 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018445 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.029616 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.038365 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.036485 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026370 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.013912 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.041876 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028176 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031688 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.030075 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.034835 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032363 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039847 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.036966 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.035223 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013499 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.042513 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.041076 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.035699 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.038904 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.022037 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.032714 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036370 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037897 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.056104 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.042548 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012138 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 851
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.427130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.441607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028644 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 50000, number of used features: 32
# [LightGBM] [Info] Start training from score 3.419890

# %%
# Calcul du Mean Squared Error (MSE) et du R2 Score
mse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Affichage des résultats
print("Mean Squared Error (MSE):", mse)
print("Coefficient de détermination (R2 Score):", r2)
# Out:
# Mean Squared Error (MSE): 2.026234179768175
# Coefficient de détermination (R2 Score): 0.6988952224649742

# %%
# test data for Kaggle submission
test = pd.read_parquet("data/nyc-taxis-tips/test_preprocessed.parquet")

test.drop(columns=["RatecodeID_6.0"], inplace=True)
# test[categorical_cols] = test[categorical_cols].astype('category')

X_sub = test.drop(cols_to_exclude, axis=1)
X_sub[columns_to_norm] = scaler.transform(X_sub[columns_to_norm])

#predictions = model_ridge_CV.predict(X_sub)
predictions = gbm.predict(X_sub)

df_pred = pd.DataFrame(predictions, columns=["tip_amount"]).reset_index().rename(columns={"index": "row_ID"})
display(df_pred.head(15))
print(sum(df_pred["tip_amount"] < 0))
df_pred.loc[df_pred.tip_amount < 0, "tip_amount"] = 0
#df_pred.to_parquet("submission/nyc-taxis-tips/regression_sub_1bis.parquet", index=False)
df_pred.to_parquet("submission/nyc-taxis-tips/boosting_sub_1.parquet", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 2
#       1 #predictions = model_ridge_CV.predict(X_sub)
# ----> 2 predictions = gbm.predict(X_sub)
#       4 df_pred = pd.DataFrame(predictions, columns=["tip_amount"]).reset_index().rename(columns={"index": "row_ID"})
#       5 display(df_pred.head(15))
#
# File ~/miniconda3/envs/deep/lib/python3.11/site-packages/lightgbm/sklearn.py:1010, in LGBMModel.predict(self, X, raw_score, start_iteration, num_iteration, pred_leaf, pred_contrib, validate_features, **kwargs)
#    1008 n_features = X.shape[1]
#    1009 if self._n_features != n_features:
# -> 1010     raise ValueError(
#    1011         "Number of features of the model must "
#    1012         f"match the input. Model n_features_ is {self._n_features} and "
#    1013         f"input n_features is {n_features}"
#    1014     )
#    1015 # retrieve original params that possibly can be used in both training and prediction
#    1016 # and then overwrite them (considering aliases) with params that were passed directly in prediction
#    1017 predict_params = self._process_params(stage="predict")
#
# ValueError: Number of features of the model must match the input. Model n_features_ is 39 and input n_features is 45
